# %%
import tensorflow as tf
facenet = tf.keras.models.load_model('/content/drive/My Drive/facenet_keras.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
facenet.output
# Out:
# <tf.Tensor 'Bottleneck_BatchNorm/Identity:0' shape=(None, 128) dtype=float32>

# %%
for layer in facenet.layers:
  layer.trainable = False

# %%
facenet.summary()
# Out:
# Model: "inception_resnet_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# Conv2d_1a_3x3 (Conv2D)          (None, 79, 79, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# Conv2d_1a_3x3_BatchNorm (BatchN (None, 79, 79, 32)   96          Conv2d_1a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_1a_3x3_Activation (Activ (None, 79, 79, 32)   0           Conv2d_1a_3x3_BatchNorm[0][0]
# __________________________________________________________________________________________________
# ...

# %%
facenet.input
# Out:
# <tf.Tensor 'input_1:0' shape=(None, 160, 160, 3) dtype=float32>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4bf8a3df-193d-4886-928e-9769b410783b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4bf8a3df-193d-4886-928e-9769b410783b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 20200717_171710.jpg to 20200717_171710.jpg

# %%
from matplotlib import image
from matplotlib import pyplot
image1 = image.imread('/content/with.jpg')
image2= image.imread('/content/without.jpg')

print(image1.dtype)
print(image1.shape)
print(image2.dtype)
print(image2.shape)
# Out:
# uint8
# (2448, 3264, 3)
# uint8
# (2448, 3264, 3)

# %%
import numpy as np
load_img_rz1 = np.array(Image.open('/content/with.jpg').resize((160,160)))
load_img_rz2 = np.array(Image.open('/content/without.jpg').resize((160,160)))

Image.fromarray(load_img_rz1).save('/content/with.jpg')
Image.fromarray(load_img_rz2).save('/content/without.jpg')

print("After resizing:",load_img_rz1.shape)
print("After resizing:",load_img_rz2.shape)
# Out:
# After resizing: (160, 160, 3)
# After resizing: (160, 160, 3)

# %%
imm1 = np.expand_dims(load_img_rz1,0)
print(imm1.shape)
imm2 = np.expand_dims(load_img_rz2,0)
imm2.shape
# Out:
# (1, 160, 160, 3)
# (1, 160, 160, 3)

# %%
y_pred1 = facenet.predict(imm1)
y_pred2 = facenet.predict(imm2)
print(y_pred1.shape)
y_pred2.shape
# Out:
# (1, 128)
# (1, 128)

# %%
 from sklearn.metrics.pairwise import cosine_similarity
 cosine_similarity(y_pred1, y_pred2)
# Out:
# array([[0.97261304]], dtype=float32)
